# %% [markdown]
# <h1><center>INFO 2950 Project Phase 5</center></h1>

# %% [markdown]
# <h1>Project Introduction</h1>
# <br>&emsp;&emsp;On January 14, 2013, the New York State Senate, following in the footsteps of the state of New Jersey, approved the Secure Ammunition and Firearms Enforcement (SAFE) act, one of the most sweeping and comprehensive firearm legislations since the Federal Gun Control Act of 1968. By 2016, to curb firearm-related violence and decrease correctional costs, California followed suit, enacting gun control regulations that mirrored New York’s. Both policy decisions specifically included high-capacity magazine bans, mandatory firearm registration, increased measures to ensure the accountability of ammunition by retailers, and intensive background checks. Such sweeping legislation resembled the 1994-2004 Assault Weapons Ban (AWB).
# <br>&emsp;&emsp;Under the Clinton era AWB, many firearms were banned over cosmetic features, magazine capacities, country of origin, and more. The outcome of the AWB remains controversial, but some subsequent trends became apparent. Immediately preceding the AWB, manufacturers accelerated production to respond to an increasing shock to consumer demand. Upon the AWB’s expiration, prices of previously banned firearms plummeted.
# <br>&emsp;&emsp;In contrast to the AWB, California and New York’s updated policies are more thorough in their approach to pistols, background checks, and ammunition registration. While these laws are controversial to the point of constitutional debate, they have precedent. As early as 1934, the National Firearms Act (NFA) restricted automatic weapons, suppressors, and short-barreled rifles (SBRs) and was continually expanded upon until the second world war. Following the assassination of President John F Kennedy, the 1960s brought additional legislation against explosives, incendiary devices, and the import of foreign weapons lacking “sporting use.” Riding a new wave of conservatism, congress passed the Firearm Owners Protection Act (FOPA) in 1986. The FOPA added privacy protections for firearm buyers and sellers, prevented the creation of a nation-wide firearms registry, and limited the ATF’s capacity to conduct inspections while simultaneously increasing restrictions on the transfer automatic weapons.
# <br>&emsp;&emsp;In the 21st century, it has become more common than before for states to pass their gun legislation due to the national divergence surrounding guns. Highlighting the recent surge in controversy around this topic, we currently live in a unique era in US history in which the details of a citizen’s gun ownership are nonchalant in some states while egregiously felonious in others.
# <br>&emsp;&emsp;Measuring and analyzing the aggregate effects of gun legislation has been difficult throughout most of the 20th century, but with the advent of computers and the polarization of gun politics since the 1990s, datasets and research has become increasingly common. Alarming trends of suicides, mass shootings, and street violence have influenced states to take a variety of stances on gun control. Thoughtful data collection, analysis, and comparison are crucial to discerning which of these solutions are most effective, how they may achieve success, and what policies are worth implementation. Within the scope of our project, we intend to separate our data between malicious gun related crimes and gun related suicides and examine how gun control policies effect each individually.

# %% [markdown]
# <h1>Link to the Data</h1>
# <a href='https://drive.google.com/drive/folders/1H5uNfRmgfnVpUDz3eeKxOKnSrmihhGJ5?usp=sharing'>https://drive.google.com/drive/folders/1H5uNfRmgfnVpUDz3eeKxOKnSrmihhGJ5?usp=sharing</a>

# %% [markdown]
# <h1>Analysis 1 Question:</h1>
# Do the gun control policies of states correlate significantly with the malicious (perpetrator on victim) gun-crime rate in each state?<br><br>
#
# <h1>Analysis 2 Question:</h1>
# Considering the assumption that most gun suicides are impulse decisions, is there a correlation between states with more restrictive gun control (specifically waiting periods) and suicide rates? <br><br>

# %% [markdown]
# <h1>Data Limitations</h1>
#
# There are many factors that influence gun crime/violence beyond the scope of our dataset. Each location and incident recorded may have unique economic, cultural, or demographic considerations that are unrecognized by our dataset. There are variables included within the data in regards to congressional district area (referenced as political leadership), however there are different levels of government, popular opinion, and outlying policy decisions that are not being taken into account. We may find it useful in the future to collect census data including population demographics and population density to better understand our dataset. Without the appropriate census data, there is a strong possibility that any following analysis may lead to skewed results.

# %% [markdown]
# <h1>Data Description</h1>
# <ol>
# <li><h5>Who was the dataset created by and funded by?</h5></li>
# The dataset was collected by a non-profit organization called Gun Violence Archive (GVA) intended to provide public access to accurate information regarding gun related incidents in the USA.
# Our particular dataset was assembled by Kaggle user James Ko combining data collected from GVA between 2013 and 2018. Using the location data recorded by GVA, the user has also included the house and senate districts where these incidents have taken place, as well as more precise location data based on the source information provided by GVA. The intent behind creation of this dataset was for exploratory analysis. The author wrote “I believe there are plenty of ways this dataset can be put to good use. If you have an interesting idea or feel like messing around with the data, then go for it.”<br><br>
# <li><h5>What data does each instance consist of? Is the sample representative of the larger set?</h5></li>
# Our dataset represents 239,676 specific instances of gun violence to include  mass-shootings, suicides, and injuries within the United States between 2013 and 2018. It also specifies the location of the incident, number of victims, and congressional districts in which the incidents occurred.
# The sample only represents gun violence within the United States and alone is not substantial to describe or predict global trends in gun violence. Within the US, the data set is all encompassing for recorded incidents of gun violence as verified by the original source (GVA).
# <li><h5>Is there a label or target associated with each instance? Is any information missing from individual instances? What processes might have influenced what data was observed and recorded and what was not?</h5></li>
# Each instance was associated with the name of its perpetrator, but we have removed their names in favor of a single “incident ID” which is identical to its associated row number in the CSV file. Additionally, while our CSV provides a vague description of some specific locations or names of venues where incidents took place, we find the categorization of the locations to be lacking. Ideally, we would have each location recorded by category such as workplace, office, public event, etc. As of now, we do not plan on exploring correlations involving this category, so it will be ignored.
# If an incident went unrecorded by police or local media sources, it obviously would not be discoverable for GVA. It is also worth noting that incidents involving guns in which nobody was physically injured or killed may be unreliable as many reported incidents of gunfire are recorded here yet nearly impossible to confirm.
# <li><h5>Are relationships between individual instances made explicit?</h5></li>Two immediate observations show that there is a consistent, possibly slowly increasing rate of gun related incidents. It is also clear that a significant majority of gun violence is perpetrated by men.
# <li><h5>Are there any errors, sources of noise, or redundancies in the dataset? If so, please provide a description.</h5></li>The initial data set included url links to reports on each incident, separate columns with address and city as well as GPS location data (all providing overlapping information). To minimize the size of the dataset, all URLs and direct links have been removed from the CSV file.
# <li><h5>Is the dataset self-contained, or does it link to or otherwise rely on external resources? If it links to or relies on external resources, are there guarantees that they will exist, and remain constant, over time; are there official archival versions of the complete dataset and are there any restrictions associated with any of the external resources that might apply to a future user?</h5></li> Considering the data is more than 3 years old now and hosted via GVA, we are confident it will remain static. For a small, predictably insignificant number of cases, some updates to police investigations may cause changes to data that we have already accepted into our set. There are no fees or restrictions should a user want to verify our data via GVA or the modified dataset on Kaggle.
# The GVA database can be accessed here: https://www.gunviolencearchive.org/
# <li><h5>Does the dataset contain data that might be offensive, insulting, threatening, or might otherwise cause anxiety?</h5></li>Yes, our dataset includes data that could cause some anxiety to individuals who are sensitive to descriptions of violence, specifically gun violence, murder, or suicide.
# <li><h5>Does the dataset identify any subpopulations? If so, please describe how these subpopulations are identified and provide a description of their respective distributions within the dataset. </h5></li>Yes, the data set contains identification of persons involved by age, age group, and gender. The primary denomination of data is male over the age of 18.
# <li><h5>Is it possible to identify individuals (i.e., one or more natural persons), either directly or indirectly (i.e., in combination with other data) from the dataset? If so, please describe how.</h5></li>Although names of perpetrators have been removed, some of the information (specifically location data) when cross referenced to police reports or news articles could reveal identities of perpetrators/victims for that incident.
# <li><h5>Does the dataset contain data that might be considered sensitive in any way? If so, please provide a description.
# Our dataset includes information regarding vague political affiliations (based on location), criminal histories, age, and sex.</h5></li>We don’t believe any of this information is sensitive as it is currently accessible in the public domain or has since been widely publicized.
# <li><h5>How was the data associated with each instance acquired?</h5></li>The data associated with each instance was initially acquired by GVA through automated queries and manual research overlapping sources from law enforcement, media reporting, and other government sources. Further links are included alongside each incident report on GVA’s website. Our initial dataset pulled from Kaggle included these links as they had been added to the dataset via a Python script. However, due to the size of the file, we decided to omit the links as we had no tangible use for them.
# <li><h5>What mechanisms or procedures were used to collect the data? How were these mechanisms or procedures validated?</h5></li>The primary mode of collection of data involved importing data sets from single queries from the Gun Violence Archive, then utilizing web scraping techniques to complete the data set due to missing existing data.
# A python script queried all incidents that occurred, scraped the data and transferred it into a CSV file
# Each data entry was augmented with additional data that was not initially derived from the query results page, such as participant information, geolocation data, etc.
# The following data was sorted in order of increasing date, then merged into a single CSV file
# <li><h5>What was the sampling strategy (e.g., deterministic, probabilistic with specific sampling probabilities)? </h5></li>This data is deterministic, it is based on firsthand police reports and subsequently supported and verified by multiple sources.
# <li><h5>Who was involved in the data collection process (e.g., students, crowdworkers, contractors) and how were they compensated (e.g., how much were crowdworkers paid)?</h5></li>The data was initially collected through GVA sources; further data collection through web scraping was completed by James Ko. First hand data, such as reports and new articles, were assembled by their respective sources and collected by GVA. James Ko’s web scraping software received its data from GVA’s web-pages related to each incident that included information absent from their posted CSV files.
# <li><h5>Over what timeframe was the data collected? Does this timeframe match the creation timeframe of the data associated with the instances (e.g., recent crawl of old news articles)? If not, please describe the timeframe in which the data associated with the instances was created.</h5></li>The time frame of the data is January 2013 to March 2018. The data set was assembled in April 15, 2018.
# <li><h5>Were any ethical review processes conducted?</h5></li>No, as far as we have found, there has not been any ethical review processes conducted upon this data.
# <li><h5>Did you collect the data from the individuals in question directly, or obtain it via third parties or other sources?</h5></li>The data was collected via third parties, specifically Kaggle and GVA.
# <li><h5>Were the individuals in question notified about the data collection?</h5></li>There is no indication that the individuals represented by our dataset were notified about the data collection.
# <li><h5>Did the individuals in question consent to the collection and use of their data?</h5></li>No consent was taken although it is also worth mentioning that our dataset is based solely on public records and does not include names or identifying information of those involved.
# <li><h5>Has an analysis of the potential impact of the dataset and its use on data subjects been conducted?</h5></li>So far no data protection impact analysis has been conducted.
# <li><h5>Was any preprocessing/cleaning/labeling of the data done?</h5></li>Basic preprocessing of the data occurred in the form of removing vestigial columns (such as large URLs) to lower the file size, as well as augment data formats for participant information, geolocation etc for ease of use in Jupyter.
# <li><h5>Was the “raw” data saved in addition to the preprocessed/cleaned/labeled data?</h5></li>The raw and unaltered version of the data we used is available via Kaggle:
# https://www.kaggle.com/jameslko/gun-violence-data
# The source used for the Kaggle composition is directly from the 2013-2018 sections of the Gun Violence Archive:
# https://www.gunviolencearchive.org/
# <li><h5>Is the software used to preprocess/clean/label the instances available? If so, please provide a link or other access point.</h5></li>GVA and James Ko described web scraping processes used in collecting and assembling this dataset, but we were unable to find the scripts that were used.
# <li><h5>Has the dataset been used for any tasks already?</h5></li>This data set has been utilized for other tasks, one being “Gun Violence Incidents in USA - Exploration” and the other being “Gun violence in the US: EDA and RShiny app”. “Gun Violence Incidents - Exploration” explore the annual deaths and injuries based off of basic metrics such as incidents/deaths/injuries based off of each individual variable, such as time of month, year, state, as well as characteristics of the incident. “Gun violence in the US: EDA and RShiny app” examines the use of the data set by comparing victims and incidents by state and city. As well as the overview of analyzing the incident categories.
# <li><h5>What (other) tasks could the dataset be used for?</h5></li>This dataset can be used to examine the locations of gun violence incidents within the US to determine which areas have been historically most affected. It could be compared to similar data from other countries or could be compared to rates of violence in the US inflicted by different mechanisms. Categorizing the venue where an incident took place may reveal more insights about how and when perpetrators choose their targets.
# <li><h5>Are there tasks for which the dataset should not be used?</h5></li>As we consider cross-referencing our set’s data on congressional districts with its rates of violence, it is important to acknowledge that political leadership is not always directly reflected in policy and certain laws or policies may not produce immediate results. There are a variety of factors at work, and our intent is to scrutinize possible correlations without committing to oversimplified heuristics. The dataset should not be used to describe whether or not a particular policy is effective. It should not be used to gauge the competency of political leadership or a particular party/belief. Our dataset is intended to examine broad swaths of various gun crimes, and mishandling such data could overstate or understate certain issues. For example, using our dataset to gauge violent crime in an area will discount the multitude of instances where violent crimes do not involve firearms. Similarly, treating all of the incidents as if they were motivated by malicious intent against another person will discount accidents, self-harm, or suicides that may not be relevant within the intended context.
#
# <li><h5>Quantifying Gun Control (ft Dummy Variables)</h5></li> To create metrics based on gun control policies, we built our own dataset called state_gun_control.csv. Unfortunately for our group, this task was too intricate to be trusted to a web scraping script, and we could not find a reliable site that collected the data we needed in a readable format. With the shifting of policies over time, it is also important that we use data within our primary dataset's timeline. We decided to collect data on policies that were enacted by a cut-off date which we specified as the half-way mark in our date-range (Aug 17th, 2015). We collected publicly available information on existing gun control policies with special attention to when they passed and were enforced in each state via their respective ".gov" websites. We divided the 50 states (51 counting Washington DC) between ourselves and manually entered dummy variables to represent the existence of a specific policy in each state. We restricted ourselves to 6 categories to discern whether or not a state had some version of a specified policy, and ended up creating over 300 unique points for our indicator dummy variables. As a general rule, 1 represents a more restrictive version of a policy is in place, 0 means there is a relaxed or non-existent policy. To elaborate further, the categories and descriptions are as follows:
# <h4>waiting_period: (Waiting Period)</h4> Describes whether or not there is a waiting period beyond 24 hours between an authorized person (typically a non-felon over 18) purchasing a firearm and legally being allowed to handle or take custody of the firearm. Could apply to rifles, pistols, or both. 1 means there is a policy in place, 0 means none.
# <h4>prch_lic_req: (License to purchase/own)</h4> The state has a policy through which one must obtain a license to be able to purchase and or own firearms and or ammunition. 1 means there is a policy requiring such a license, 0 means there is none.
# <h4>cc_rstct: (Restrictions on Concealed Carry)</h4> The state bans citizens from carrying firearms in a concealed manner (under the seat of a car, inside a jacket, etc) in public spaces or citizens require a special license to do so. Typically these laws only apply to public spaces, but there are some cases where it may be illegal to conceal a firearm in a private setting as well.
# <h4>mag_rstct: (Restrictions on Magazine Capacity)</h4> A state ban or restriction on magazines (*removeable spring loaded vessels containing cartridges that will feed into a firearm as the bolt cycles). This variable specifically pertains to bans on magazines for semi-automatic firearms excluding shotguns. Many states have magazine restrictions on shotguns or specifically shotguns intended for the hunting of waterfowl. Such laws are intended to protect wildlife from unethical hunting practices or other case by case scenarios. Considering the unlikelihood of shotgun tube length restrictions having any impact on firearm related incidents, we opted to ignore such policies and only include bans that restrict the purchase and or possession of magazines designed for semi-automatic gas-operated firearms regardless of the exact cartridge limit enforced.
# <h4>oc_rstrct: (Restrictions on Open Carry)</h4> The state bans citizens from carrying firearms openly or citizens require a special license to do so. This specifically pertains to public spaces and not hunting grounds, as there are many states that allow open carry in specified hunting areas or private property but restrict individuals from carrying in public areas (streets, parks, etc). 1 reflects restrictions on open carry in public, 0 reflects what is referred to in many states as "constitutional carry" or an implicit right to carry firearms in public.
# <h4>style_rstrct: (Restrictions on Stylistic/Cosmetic Features)</h4> This category is the most encompassing of our dummy variables. It includes states that have their own lists of make, model, or manufacturer bans or a ban against cosmetic features, functional features, or attachments. For example, New Jersey bans adjustable stocks and muzzle-brakes (or recoil compensators). California bans rifles with pistol grips, folding stocks, foregrips, and underbarrel flare launchers. Some states ban specific firearms by name such as the AR15 or FN Hi-Power with similar justification to the feature/cosmetic bans. Regardless, the nature of these laws converge at their intent to eliminate certain firearms such as large handguns and gas-operated semi-automatic rifles (often erroneously referred to as automatic or assault rifles). Due to the Federal ban of automatic-weapons, any states that only ban features or firearms that are already illegal under Federal law (such as fully-automatic firearms or Chinese imports) are excluded from this identifier. A 1 means a state has a policy matching this description and 0 means there are no policies that meet these criteria.

# %% [markdown]
# <h1>Data Analysis</h1>

# %%
# Imports
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
from matplotlib import pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# <h1>Data Cleaning</h1>
#
# Our original dataset can be found at the following link: https://www.kaggle.com/jameslko/gun-violence-data
# In the original dataset, there are 28 columns, which include:
#
# incident_id, date, state, city_or_county, address, n_killed, n_injured, incident_url, source_url, incident_url_fields, congressional_district,
# gun_stolen, gun_type, incident_characteristics, latitude, location_description, longitude, n_guns_involved, notes, participant_age, participant_age_group,
# participant_gender, participant_name, participant_relationship, participant_status, participant_type, sources, state_house_district, and state_senate_district
#
# Since this original dataset is 149.7MB, we needed to reduce it in order to upload it to GitHub and to meet the project dataset size constraints. Many of the columns
# in the original dataset do not relate to our intended analyses, and of the columns that do relate, some of them, such as gun_type, are unusably incomplete.

# %%
# Load the modified dataset
gv_df = pd.read_csv("shootings_modified.csv")

# Ultimately, we only end up using the following columns from shootings_modified.csv
shootings_df = gv_df[['date', 'state', 'n_killed', 'n_injured', 'incident_characteristics', 'participant_age']]
num_shootings = len(shootings_df)

# Display the number of shootings in the dataset
print(f'Number of incidents in shootings dataset: {num_shootings}')

earliest_date = shootings_df['date'].min()
latest_date = shootings_df['date'].max()

# Display the date range of the dataset
print(f'The shootings dataset ranges from {earliest_date} to {latest_date}')
# Note: the midpoint of the date range is 2015-08-17 (manually calculated)

# Display the first few rows of the data
shootings_df.head(3)
# Out:
# Number of incidents in shootings dataset: 239677
# The shootings dataset ranges from 2013-01-01 to 2018-03-31
#          date         state  n_killed  n_injured  \
# 0  2013-01-01  Pennsylvania         0          4
# 1  2013-01-01    California         1          3
# 2  2013-01-01          Ohio         1          3
#
#                             incident_characteristics  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 2  Shot - Wounded/Injured||Shot - Dead (murder, a...
#
#                      participant_age
# 0                              0::20
# 1                              0::20
# 2  0::25||1::31||2::33||3::34||4::33

# %%
# state_gun_control.csv is data we have collected ourselves from a legal reference website
# https://www.findlaw.com/state/criminal-laws/gun-control.html and state specific .gov sites.

# Load the data -- policies 
gun_control_df = pd.read_csv("state_gun_control.csv")
gun_control_df['rstrct_lvl'] = gun_control_df.sum(axis=1,numeric_only=True)
gun_control_df.head(3)
# Out:
#      state  waiting_period  prch_lic_req  cc_rstct  mag_rstct  oc_rstrct  \
# 0  Alabama               0             0         1          0          0
# 1   Alaska               0             0         0          0          0
# 2  Arizona               0             0         1          0          0
#
#    style_rstrct  rstrct_lvl
# 0             0           1
# 1             0           0
# 2             0           1

# %%
# Load census data and show first few rows
census_data = pd.read_csv("state_pop_est_2015.csv")
census_data['state'] = census_data.state.replace(' ', '')

# %%
# Load census data and show first few rows
census_data = pd.read_csv('state_pop_est_2015.csv')
census_area = pd.read_csv('state_area.csv')
drop_rows = 'Puerto Rico','Northern Mariana Islands','United States Virgin Islands','American Samoa','Guam'
for i in drop_rows:
    census_area = census_area[~census_area.state.str.contains(i)]

census_data = census_data.sort_values(by=['state'], axis=0)
census_data = census_data.reset_index().drop(columns='index')
census_area = census_area.sort_values(by=['state'], axis=0)
census_area = census_area.reset_index().drop(columns='index')
census_area.state = census_data.state
# Census data now contains km2 describing state's area
census_data = census_data.merge(census_area, how = 'inner', on= 'state')
census_data['2015_pop_est'] = pd.to_numeric(census_data['2015_pop_est'])
census_data['km2'] = census_data['km2'].str.replace(',','')
census_data['km2'] = pd.to_numeric(census_data['km2'])
census_data['density'] = (census_data['2015_pop_est'])/census_data['km2']

states = census_data.state.tolist()

def add_census_value(df_in, df_pull, col, states):
    df = df_in.copy()
    df[col] = df.state
    for i in states:
        new_col = int(df_pull.loc[(df_pull.state==i)][col].sum())
        df[col] = df[col].replace({i: new_col}, inplace=False)
        
    df_out = df
    return df_out

# combine gun control variables into the dataframe
census_data = pd.concat([census_data, gun_control_df.drop(columns=['state'])], axis=1)

# %%
# Determine suicides based on number killed == 1; number injured == 0; incident specifically mentions word suicide
# (using 'uicide' to avoid capitalization)
warnings.filterwarnings('ignore')
shootings_df['suicide'] = np.where((shootings_df['incident_characteristics'].str.contains('uicide',na=False))
                                & (shootings_df['n_killed'] == 1) & (shootings_df['n_injured'] == 0) &
                                ~shootings_df['participant_age'].str.contains('1::',na=False), 1, 0)

violent_shootings = shootings_df[shootings_df['n_killed']+shootings_df['n_injured'] != 0]
deadly_shootings = shootings_df[shootings_df['n_killed'] != 0]

# %%
# Separate shootings_df into non-suicides and suicides
vlnt_df = shootings_df[shootings_df['suicide'] != 1]

aslt_df = census_data.copy()
aslt_df = add_census_value(aslt_df, vlnt_df, 'n_killed', states)
aslt_df = add_census_value(aslt_df, vlnt_df, 'n_injured', states)
aslt_df['n_incd'] = aslt_df['n_killed']+aslt_df['n_injured']

print(f'Proportion shootings that were deadly: {round(len(deadly_shootings)/len(shootings_df),3)}')
# Calculate proportion of deadly shootings that were suicides
census_data.head(10)
# Out:
# Proportion shootings that were deadly: 0.225
#                   state  2015_pop_est      km2      density  waiting_period  \
# 0               Alabama       4852347   135767    35.740254               0
# 1                Alaska        737498  1723337     0.427948               0
# 2               Arizona       6829676   295234    23.133094               0
# 3              Arkansas       2978048   137732    21.622049               0
# 4            California      38918045   423967    91.794986               1
# 5              Colorado       5450623   269601    20.217369               0
# 6           Connecticut       3587122    14357   249.851780               1
# 7              Delaware        941252     6446   146.021098               0
# 8  District of Columbia        675400      177  3815.819209               1
# 9               Florida      20209042   170312   118.658944               1
#
#    prch_lic_req  cc_rstct  mag_rstct  oc_rstrct  style_rstrct  rstrct_lvl
# ...

# %% [markdown]
# <h1>Analysis 1</h1>
# <strong>Question:</strong><br>
# Do the gun control policies of states correlate significantly with the malicious (perpetrator on victim) gun-crime rate in each state?<br><br>
# <strong>Method:</strong><br>
# We intend to determine this through a multilinear regression model involving the use of predictor (dummy) variables such as: whether or not a state has magazine limit restrictions, waiting periods, cosmetic/accessory bans, and ammunition liscencing. We can achieve this by independently researching outstanding states to create a dictionary summarizing their specific policies. Furthermore, We can add up the presence of these policies to compare a sample value of enacted gun control policies to evaluate if the overall presence of more gun control policies may correlate with a a change in gun crimes.<br>

# %%
aslt_per_100k = aslt_df.copy()
aslt_per_100k['n_killed_p100'] = (aslt_df['n_killed']/aslt_df['2015_pop_est'])*10**5
aslt_per_100k['n_injured_p100'] = (aslt_df['n_killed']/aslt_df['2015_pop_est'])*10**5
aslt_per_100k['n_incdnts_p100'] = (aslt_df['n_incd']/aslt_df['2015_pop_est'])*10**5

aslt_per_100k.head(10)
# Out:
#                   state  2015_pop_est      km2      density  waiting_period  \
# 0               Alabama       4852347   135767    35.740254               0
# 1                Alaska        737498  1723337     0.427948               0
# 2               Arizona       6829676   295234    23.133094               0
# 3              Arkansas       2978048   137732    21.622049               0
# 4            California      38918045   423967    91.794986               1
# 5              Colorado       5450623   269601    20.217369               0
# 6           Connecticut       3587122    14357   249.851780               1
# 7              Delaware        941252     6446   146.021098               0
# 8  District of Columbia        675400      177  3815.819209               1
# 9               Florida      20209042   170312   118.658944               1
#
#    prch_lic_req  cc_rstct  mag_rstct  oc_rstrct  style_rstrct  rstrct_lvl  \
# ...

# %%
# Create the linear model

regr = linear_model.LinearRegression()
predictors = ['density', 'waiting_period', 'prch_lic_req', 'cc_rstct', 'mag_rstct', 'oc_rstrct', 'style_rstrct']
X = aslt_per_100k[predictors]
Y = aslt_per_100k['n_killed_p100']
regr.fit(X, Y)

mod = sm.OLS(Y, X)
res = mod.fit()
print(res.summary())

# print the coefficients of the gun control measures as predictors in the multilinear model:
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          n_killed_p100   R-squared (uncentered):                   0.730
# Model:                            OLS   Adj. R-squared (uncentered):              0.687
# Method:                 Least Squares   F-statistic:                              16.95
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):                    1.26e-10
# Time:                        19:56:02   Log-Likelihood:                         -169.25
# No. Observations:                  51   AIC:                                      352.5
# Df Residuals:                      44   BIC:                                      366.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# the independent variables set
predictors = aslt_per_100k[['density', 'waiting_period', 'prch_lic_req', 'cc_rstct', 'mag_rstct', 'oc_rstrct', 'style_rstrct']]

# VIF dataframe 
vif_data = pd.DataFrame()
vif_data["feature"] = predictors.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#           feature       VIF
# 0         density  1.295882
# 1  waiting_period  3.330283
# 2    prch_lic_req  2.948378
# 3        cc_rstct  1.747274
# 4       mag_rstct  2.993244
# 5       oc_rstrct  2.513006
# 6    style_rstrct  3.147971

# %%
# Correlations between all values
labels = ['2015 Population Estimate','Area in km^2','Population Density','Waiting Period','License Required','Concealed Carry Restriction','Magazine Restrictions',
    'Oven Carry Restriction','Style Restriction', 'Restriction Level', 'Number Killed', 'Number Injured','Number of Incidents','Number Killed/100k',
    'Number Injured/100k','Number Incidents/100k']

sns.heatmap(aslt_per_100k.corr(),xticklabels=labels,yticklabels=labels, center=0)
plt.tight_layout()
plt.title("Correlation between all variables by State")
plt.show()

# %%
labels = ['State Pop. Density','Waiting Period','License Req. to Purchase','Concealed Carry Restrictions','Magazine Capacity Restrictions',
    'Open Carry Restrictions','Cosmetic Restrictions','Overall Restrictiveness','Total Incidents per 100k']

sns.heatmap(aslt_per_100k[['density','waiting_period','prch_lic_req','cc_rstct','mag_rstct','oc_rstrct','style_rstrct','rstrct_lvl','n_incdnts_p100']].corr(), 
            xticklabels=labels, yticklabels=labels, center=0)
plt.tight_layout()
plt.title('Correlation Between Gun Incidents per 100k and Policy')
plt.show()

# %% [markdown]
# The above results show that states with concealed carry laws often do not have the other types of restrictions and vice versa. It also appears that there is only a minor correlation between population density and the overall presence of state gun control.
#
# The most striking correlation is between the number of incidents per 100,000 people is population density. It is also worth mentioning the slight (roughly 0.4) correlation between stylistic restrictions and number of incidents. This could indicate that the stylistic restrictions are ineffective, but it may also be that the states suffering more from gun-violence will be more likely to pass any sort legislation relating to gun-control.

# %%
print("Differences per average number killed per 100k per state based on restriction level:\n")

for i in range(6):
    leq = aslt_per_100k[aslt_per_100k['rstrct_lvl'] <= i]
    geq = aslt_per_100k[aslt_per_100k['rstrct_lvl'] > i]

    per_state_leq = leq['n_killed_p100'].sum() / len(leq)
    per_state_geq = geq['n_killed_p100'].sum() / len(geq)
    result = round(per_state_geq - per_state_leq,3)
    print(f'<={i} compared with >={i+1} restrictions: Difference of {result}\n')
print('Positive value difference shows that state(s) with more restrictions had fewer deaths.')
# Out:
# Differences per average number killed per 100k per state based on restriction level:
#
# <=0 compared with >=1 restrictions: Difference of 1.161
#
# <=1 compared with >=2 restrictions: Difference of -1.881
#
# <=2 compared with >=3 restrictions: Difference of -3.186
#
# <=3 compared with >=4 restrictions: Difference of -2.522
#
# <=4 compared with >=5 restrictions: Difference of -1.692
#
# <=5 compared with >=6 restrictions: Difference of -0.839
#
# Positive value difference shows that state(s) with more restrictions had fewer deaths.

# %% [markdown]
# <h1> Analysis 1 Interpretation</h1>
# What our findings indicate:

# %% [markdown]
# #### "Do the gun control policies of states correlate significantly with the malicious (perpetrator on victim) gun-crime rate in each state?"
#
# In our exploratory analysis we examine different methods to determine the efficacy of fire arm restrictions.
#
#     To begin, we conducted a VIF (variance inflation factor) which is a measure of the ratio of the variance of estimating parameters in a model, and hence the measure of the amount of multicollinearity in the set of regression variables; in this case our multiple varibles happen to be our predictors or state legislations. We would like to preface our later models in light of the VIF considering the multifactor nature of the data we're observing. The low VIF is indicative that we're not passing variables that are causing multicollinearity issues.
#
#    In the initial heatmap, individual variables, and their correlative coefficiency can be observed. For example, there is a direct relation between density and the number of incidents per 100,000 people. This is to be expected, considering the moderate relationship between population density, population, and crime statistics; however variable that relationship is to other factors such as poverty etc. (See Harries, 2006 and Nolan, 2004) In "Correlation between all variables", we observe a very poor relationship between number of killed, injured, and incidences; indicative to a very inconclusive initial observation between the efficacy of gun control on related crime statistics. Our hypothesis towards the relatively poor correlation between the deaths, injuries, and incidences to each of our predictors is the possibility that individually the predictors are a poor predictor, however in a combination they result in a higher correlatable relationship between decrease of deaths and increase in added predictor values.
#
#    To further delve into the the inconclusive nature of gun control legislation, we created a model ("Correlation Between Predictor Values"). It appears that there is a strong correlation between the implementation of certain legislation and the subsequent implementation of other pieces of gun control legislation. Case in point, states that have waiting periods, seem to subsequently also have legislation for the adaptation of purchasing license requirements, as well as style restrictions. States that adopt style restrictions happen to also be very prone to adapt magazine restriction legislation. However this is all in light of the relatively poorer relationship between all the predictors compared to number of incidences per 100k. This could be a indication that states adopt gun control policy not in reaction to gun related crimes, but more so in succession or cohesion with other gun control legislative pieces. This could also support our hypothesis that no individual predictor is adopted to prevent violent gun related crimes, rather a synergy of multiple gun control legislations.
#
#    Observing the relatively inconclusive relationship between gun legislation and number killed, injured, and incidences per 100k (population), we conducted a linear regression model between number of killed to further isolate the relationship between implementation of gun-control legislation to decrease or increase of crime; utilizing number of killed as the sole metric for violent crime increases. Our findings are by far, much more conclusive this time around. The adjusted R-squared value of 0.647 for the overall linear regression is strong indication that we have a relatively good correlation in our linear regression between the decrease of deaths to increase of a certain combination of these predictor variables. This produces strong evidence that our auxiliary hypothesis that a combination of gun-control legislations decrease violent-crime is most likely true; and that the poor correlation between the predictors(individual gun-control legislations) and number of deaths is caused by a the fact that they are not correlated in a certain combination.
#
#    Furthermore, what can be distilled from that correlation coefficients is that concealed carry restrictions are a very poor form of gun-control, commonly leading to more deaths, as the coefficient is positive between CC-restrictsions and deaths; meaning that an increase in CC-restrictions directly result in an increase in deaths. This is further supported by a low P-value of the predictor value. We could possibly come to the conclusion that legislation such as the waiting periods, purchasing license requirements, and magazine restrictions are effective forms of gun control considering the decrease in deaths; however with higher p-values, we tread quite cautiously in coming to such conclusion.
#
#    Overall based on the data and the p-values as well as the variability in coefficients depending on the amalgamation of predictors, the overall conclusion that can be drawn is that there is still a great amount of uncertainty as well as inconclusiveness in the ability to correlate specific gun-control legislation to decrease in violent gun-related crimes. This should also fall on the the heels of the fact that certain data points used to measure metrics of violent crime are inheriently moderate in relation; i.e. the relation between population density to crime rates, the relation of crime rate to violent gun crimes to poverty. All of the above metrics cause uncertainty and variability in the base metrics that we utilized.

# %% [markdown]
# <h1>Analysis 2</h1>
# <strong>Question:</strong><br>
# Considering the assumption that most gun suicides are impulse decisions, is there a correlation between states with more restrictive gun control (specifically waiting periods) and suicide rates? <br><br>
# <strong>Method:</strong><br>
# This will be examined using a multilinear regression with dummy variables representing specific policies across multiple states. In some cases if there is a rise or fall in gun-suicides interrupting an apparantly consistent trend, we may track our results using a logistic regression model.

# %%
# dataframe for all suicides from years 2014-2017
# Data source is the CDC
# https://www.cdc.gov/nchs/pressroom/sosmap/suicide-mortality/suicide.htm
scde_cdc_df = pd.read_csv('state_suicides_14_17.csv')

#Dictionary of state abbreviations
state_abs = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'District of Columbia': 'DC', 'Delaware': 'DE',
    'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL',
    'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA',
    'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI',
    'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT',
    'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND',
    'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA',
    'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
    'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}
# backwards dict, had to flip vals
state_abs = {abr: name for name, abr in state_abs.items()}
scde_cdc_df.state = scde_cdc_df.state.map(state_abs)
scde_cdc_df.death_by_suicide = scde_cdc_df.death_by_suicide.str.replace(',','')
scde_cdc_df.death_by_suicide = pd.to_numeric(scde_cdc_df.death_by_suicide)

#changed to the year 2015 ONLY
scde_cdc_df_14 = scde_cdc_df[scde_cdc_df.year == 2014]
scde_cdc_df_15 = scde_cdc_df[scde_cdc_df.year == 2015]
scde_cdc_df_16 = scde_cdc_df[scde_cdc_df.year == 2016]

# %%
# Create variable to store shootings that were suicides
scde_gun_raw = deadly_shootings[deadly_shootings['suicide'] == 1]
# Fix dates for suicides to line up with dates for our CDC total
scde_gun_raw_14 = scde_gun_raw[scde_gun_raw.date > '2014']
scde_gun_raw_14 = scde_gun_raw[scde_gun_raw.date < '2015']
scde_gun_raw_15 = scde_gun_raw[scde_gun_raw.date > '2015']
scde_gun_raw_15 = scde_gun_raw[scde_gun_raw.date < '2016']
scde_gun_raw_16 = scde_gun_raw[scde_gun_raw.date > '2016']
scde_gun_raw_16 = scde_gun_raw[scde_gun_raw.date < '2017']
# create census based dataframe for suicides
scde_df_14 = census_data.copy()
scde_df_14 = add_census_value(scde_df_14, scde_gun_raw_14, 'n_killed', states)
scde_df_14 = add_census_value(scde_df_14, scde_cdc_df_14, 'death_by_suicide', states)
scde_df_14['year'] = 2014
scde_df_15 = census_data.copy()
scde_df_15 = add_census_value(scde_df_15, scde_gun_raw_15, 'n_killed', states)
scde_df_15 = add_census_value(scde_df_15, scde_cdc_df_15, 'death_by_suicide', states)
scde_df_15['year'] = 2015
scde_df_16 = census_data.copy()
scde_df_16 = add_census_value(scde_df_16, scde_gun_raw_16, 'n_killed', states)
scde_df_16 = add_census_value(scde_df_16, scde_cdc_df_16, 'death_by_suicide', states)
scde_df_16['year'] = 2016

scde_df = pd.merge(scde_df_14, scde_df_15, how='outer')
scde_df = pd.merge(scde_df, scde_df_16, how='outer')
#Drop DC, too much of an outlier
scde_df = scde_df[scde_df.state != 'District of Columbia']
# killed per 100k (no suicide injuries/attempted suicides included)
scde_per_100k = scde_df.copy()
scde_per_100k['fract_scde_gun'] = (scde_per_100k['n_killed']/scde_per_100k['death_by_suicide'])
scde_per_100k['n_killed_p100'] = (scde_per_100k['n_killed']/scde_per_100k['2015_pop_est'])*10**5
scde_per_100k['n_scde_p100'] = (scde_per_100k['death_by_suicide']/scde_per_100k['2015_pop_est'])*10**5
scde_per_100k['not_gun_scde_p100'] = (scde_per_100k['n_scde_p100']-scde_per_100k['n_killed_p100'])

# %%
regr = linear_model.LinearRegression()
predictors = ['waiting_period', 'prch_lic_req', 'cc_rstct', 'mag_rstct', 'oc_rstrct', 'style_rstrct']
X = scde_per_100k[predictors]
Y = scde_per_100k['n_killed_p100']
regr.fit(X, Y)

mod = sm.OLS(Y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          n_killed_p100   R-squared (uncentered):                   0.587
# Model:                            OLS   Adj. R-squared (uncentered):              0.570
# Method:                 Least Squares   F-statistic:                              34.10
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):                    2.16e-25
# Time:                        19:57:37   Log-Likelihood:                         -363.55
# No. Observations:                 150   AIC:                                      739.1
# Df Residuals:                     144   BIC:                                      757.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# lets see how these change the fraction of the suicides that are gun-related
regr = linear_model.LinearRegression()
predictors = ['waiting_period', 'prch_lic_req', 'cc_rstct', 'mag_rstct', 'oc_rstrct', 'style_rstrct']
X = scde_per_100k[predictors]
Y = scde_per_100k['fract_scde_gun']
regr.fit(X, Y)

mod = sm.OLS(Y, X)
res = mod.fit()
print(res.summary())

# and see if there's a correlation between non-gun suicides
regr = linear_model.LinearRegression()
predictors = ['waiting_period', 'prch_lic_req', 'cc_rstct', 'mag_rstct', 'oc_rstrct', 'style_rstrct']
X = scde_per_100k[predictors]
Y = scde_per_100k['not_gun_scde_p100']
regr.fit(X, Y)

mod = sm.OLS(Y, X)
res = mod.fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:         fract_scde_gun   R-squared (uncentered):                   0.595
# Model:                            OLS   Adj. R-squared (uncentered):              0.579
# Method:                 Least Squares   F-statistic:                              35.32
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):                    4.94e-26
# Time:                        20:03:53   Log-Likelihood:                          35.695
# No. Observations:                 150   AIC:                                     -59.39
# Df Residuals:                     144   BIC:                                     -41.33
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
labels = ['State Pop. Density','Waiting Period','License Req. to Purchase','Magazine Capacity Restrictions','Open Carry Restrictions',
    'Cosmetic Restrictions','Overall Restrictiveness','Gun Suicides per 100k','Other Suicides per 100k', 'Total Suicides per 100k',
    'Fraction of Suicides via Firearm']

sns.heatmap(scde_per_100k[['density','waiting_period','prch_lic_req','mag_rstct','oc_rstrct','style_rstrct','rstrct_lvl','n_killed_p100',
    'not_gun_scde_p100', 'n_scde_p100', 'fract_scde_gun']].corr(), xticklabels=labels, yticklabels=labels, center=0)

plt.title('Correlation Between gun suicides per 100k, policy, and overall suicides')
plt.tight_layout()
plt.show()

# %% [markdown]
# There appears to be a negative relationship between the implimentation restrictive gun policies and the total suicides in a state. It appears that most of this reduction is connected to non-gun related suicides and not suicides commited by gun. This means there is little correlation between the specific gun policies and gun suicide rates, but there is a tendancy for states that impliment gun control to have a lower overall rate of suicide. This could be due to other policies that they have, or it could be that more densely populated places have lower rates of suicide.

# %%
plt.style.use('seaborn-poster')

scde_per_100k = scde_per_100k.sort_values(by=['n_scde_p100'])
log_dens = np.log(scde_per_100k['density']) 
lr_scde = linear_model.LinearRegression().fit(scde_per_100k[['n_scde_p100']], log_dens)
coef = lr_scde.coef_[0]
intercept = lr_scde.intercept_
y_pred = np.exp(intercept) * np.exp(coef * scde_per_100k['n_scde_p100'])


plt.scatter(scde_per_100k['n_scde_p100'], scde_per_100k['density'], alpha=0.5)
plt.plot(scde_per_100k['n_scde_p100'], y_pred, c='lime', alpha=0.8)
plt.title('Suicide / Density Model')
plt.xlabel('Suicides')
plt.ylabel('Pop. Density')
plt.show()

# %% [markdown]
# Population density is a large indicator for overall suicides, so lets see how that compares when we separate gun suicides and non-gun suicides.

# %%
sns.lineplot(
    data=scde_per_100k,
    x='n_scde_p100',
    y=y_pred,
    color='lime')

sns.scatterplot(
    data=scde_per_100k,
    x='n_killed_p100', 
    y='density',
    palette = 'flare_r',
    alpha = 0.9,
    marker='.',
    hue = 'rstrct_lvl',
    legend = False
)
sns.scatterplot(
    data=scde_per_100k,
    x='not_gun_scde_p100',
    y='density',
    palette = 'flare_r',
    alpha = 0.9,
    marker='x',
    hue = 'rstrct_lvl',
    legend = True
)
plt.title('Gun Suicides Compared to Pop. Density')
plt.xlabel('Suicides per 100k (dots = gun) (x = non-gun)')
plt.ylabel('Population Density (people per km^2)')
plt.legend(title='Level of Gun Control')
plt.show()

# %% [markdown]
# Observing the regression for overall suicides masked over a distribution of gun / non gun suicides shows a trend where the low density states have higher suicide rates involving both guns and other means. The low level of gun control seems tied to the population density of the state, but it also appears that there is lacking data on states with higher levels of gun control. The states with high levels of gun control are still rather distributed, so it is unclear as to whether or not their gun control policies are inpacting suicide rates.

# %%
restrictions = 'waiting_period', 'prch_lic_req', 'mag_rstct', 'oc_rstrct', 'style_rstrct'
restrct_dct = {'waiting_period':'Waiting Period',
               'prch_lic_req':'Purchase Lisence Required',
               'mag_rstct':'Magazie Limits', 'oc_rstrct':'Open Carry Restriction',
               'style_rstrct':'Style Restriction'}

for i in restrictions:
    sns.lineplot(
        data=scde_per_100k,
        x='n_scde_p100',
        y=y_pred,
        color='lime')
    
    sns.scatterplot(
        data=scde_per_100k,
        x='n_killed_p100', 
        y='density',
        alpha = 0.9,
        marker='o',
        hue = i,
        legend = False
    )
    sns.scatterplot(
        data=scde_per_100k,
        x='not_gun_scde_p100',
        y='density',
        alpha = 0.4,
        marker='x',
        hue = i,
        legend = True
    )
    plt.title('Gun Suicides Compared to Pop. Density')
    plt.xlabel('Suicides per 100k (dots = gun) (x = non-gun)')
    plt.ylabel('Population Density (people per km^2)')
    plt.legend(title=restrct_dct.get(i))
    plt.show()

# %% [markdown]
# It appears each individual policy has somewhat random effects, with the open carry restriction and purchase license requirements showing the most dispersed results.

# %% [markdown]
# <h1>Analysis 2 Interpretation</h1>

# %% [markdown]
# It appears that the overall correlation between gun control measures and gun related suicides per 100k people in each state is negligable compared to the massive impact that population density has. While it does appear there are cases where increased gun control correlates with a decrease in deaths, it appears that the trend is influencing both gun and non-gun suicides. This indicates that states with high levels of gun control may also have other policies or cultural factors that are influencing this outcome. Moreso, it appears the largest correlation involving gun control is the connection between population density and increased gun control.
#
# The R^2 for our regression model is nearly 0.59, showing a statistically significant trend between our selected gun laws in each state and the number of suicides. At the same time, we found that there is an even stronger correlation between the fraction of suicides by gun and an even higher correlation linking gun laws to non-gun suicides. The magazine restrictions have a strong correlation with a slight increase in suicides overall, and concealed carry restrictions in particular have 0 correlation with the number of suicides that are performed by gun compared to other mechanisms (while all of the other policies show a slightly higher p-value). The strongest correlation we found is that laws against open carrying firearms (carrying guns in public spaces) has a massive (0.9+) p-value with a very slight uptick in deaths per 100,000 residents. It is clear that states with higher population densities are more likely to ban the open carry of firearms, so there are likely other factors at play. What is immensely clear is that restrictions on public open-carry of firearms do not reduce suicide rates.
#
# It appears that the individual correlations between most gun control measures and gun related suicides per 100k people in each state are negligable either in correlation or in their effect per 100,000 residents. The effects that do exist seem to be due to factors other than gun-control policies. There is some indication that waiting periods help reduce suicides until we consider the low p-values in both the rates of gun-suicide and the fraction of suicides by gun. While it does appear there are cases where increased gun control correlates with a decrease in deaths, it appears that the trend is influencing both gun and non-gun suicides. This indicates that states with high levels of gun control may also have other policies or cultural factors that are influencing this outcome. Moreso, it appears the largest correlation involving gun control is the connection between population density and increased gun control.
# <br>In order to expand on this analysis, it would be useful to wait and collect more data to observe a difference over a long period of time for states that impliment more gun control measures or states with gun control measures roll back their policies. It may be beneficial to cross-reference the gun-specific policies with other decisions regarding the state's mental health, law enforcement, and other laws that may also be effecting suicide rates in a state.
